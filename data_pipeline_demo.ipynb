# %%
import random

# Generate 100 dummy users
data = [(i, f"User_{i}", random.randint(100, 500)) for i in range(1, 101)]

df = spark.createDataFrame(data, ["id", "name", "score"])
df.show()

# %%
# %pip install dbdemos

# %%
dbdemos.install('ai-agent')

# %%
import dbdemos
dbdemos.install('aibi-customer-support', catalog='main', schema='dbdemos_aibi_customer_support')
